# %%
import geoplanar
import geopandas
# Out:
# /Users/noraizasif/opt/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %%
HOLC_census = geopandas.read_file("holc_census_tracts.shp")
HOLC_census.plot()

# %%
HOLC_census.head()
# Out:
#   holc_id holc_grade  id  polygon_id  sheets                        name  \
# 0      C2          C  10         230       1  West End and Oakwood Place
# 1      C1          C  13        8504       0                        None
# 2     D63          D  16        7493       1                        None
# 3     C33          C  16        7612       1                        None
# 4      B9          B  16        7760       1                        None
#
#   municipali  holc_area  year  msamd state_code county_cod census_tra  \
# 0       None   0.841822  2019  13820         01        073     003900
# 1       None   2.141216  2019  30780         05        119     001100
# 2       None   5.159042  2019  31084         06        037     576403
# 3       None   0.620616  2019  31084         06        037     183220
# 4       None   0.885915  2019  31084         06        037     141304
#
#          geoid  tract_prop  holc_prop  map_id                st_name state  \
# ...

# %%
CA = HOLC_census[HOLC_census['state_code'].str.lower().str.contains('06')]
CA
# Out:
#      holc_id holc_grade  id  polygon_id  sheets  \
# 2        D63          D  16        7493       1
# 3        C33          C  16        7612       1
# 4         B9          B  16        7760       1
# 5        C46          C  16        7792       1
# 6        B33          B  16        7798       1
# ...      ...        ...  ..         ...     ...
# 8213      D6          D  22         890       1
# 8214     C14          C  22         891       1
# 8216     C14          C  22         891       1
# 8217     C14          C  22         891       1
# 8218      D5          D  22         892       1
#
#                                       name municipali  holc_area  year  msamd  \
# 2                                     None       None   5.159042  2019  31084
# 3                                     None       None   0.620616  2019  31084
# 4                                     None       None   0.885915  2019  31084
# ...

# %%
CA.plot()

# %%
from shapely.geometry import box

clipper = geopandas.GeoDataFrame(geometry =[box(-118, 34, -118.5, 34.75)])

# %%
California_data = geopandas.clip(clipper, HOLC_census)
# Out:
# <ipython-input-24-69c72ba045cc>:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   California_data = geopandas.clip(clipper, HOLC_census)

# %%
California_data.plot()
